# %% [markdown]
# # Hello dear peer reviewers!
#
# We thought that this pop-up would make sure to get you all set up and ready to go without having to lift a finger (well, almost).
#
# We want to apologize for not making it available to do straight away, but it took a little bit of love to get the project in a reviewable state.
#
# To set up the project put this notebook in a folder of your liking and run the next box. The project will be downloaded and the current directory will become the "Home" of our project from where all relative paths will branch out of.

# %%
## do visual pipeline of project

# %%
import os

#make sure it the working directory has the same path as the notebook
print(os.getcwd())

#if not, uncomment the following line and enter path manually
#os.chdir("/full/path/to/your/notebook/folder")

# %%
# Set up camp and start the review!
# !wget 'https://polybox.ethz.ch/index.php/s/EZqJtjFm7qbMcjm/download' -O Download.zip
# !unzip -o Download.zip -d .
# !rm Download.zip
# !mv ./Notebooks/* .
# !rmdir ./Notebooks

# %% [markdown]
# The following command will add a .sh file that can be used to set up the euler environment and downloads scripts that will be used for the project. Please before running them go through them once and Ctrl+F substitute 'emotta', 'fabazi' and 'hyiyang' with your username. To set up the environment download the Euler_setup.sh file and upload it to the ${HOME} folder on Euler, then run it with:
# *Bash Euler_setup.sh*

# %%
# !wget 'https://polybox.ethz.ch/index.php/s/YnKpfncmEjfRpqn/download' -O ./Euler_setup.sh
# Out:
# --2025-12-10 18:13:13--  https://polybox.ethz.ch/index.php/s/YnKpfncmEjfRpqn/download
# Resolving polybox.ethz.ch (polybox.ethz.ch)... 129.132.71.243
# Connecting to polybox.ethz.ch (polybox.ethz.ch)|129.132.71.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 393 [text/x-shellscript]
# Saving to: ‘./Euler_setup.sh’
#
# ./Euler_setup.sh    100%[===================>]     393  --.-KB/s    in 0s
#
# 2025-12-10 18:13:13 (200 MB/s) - ‘./Euler_setup.sh’ saved [393/393]

# %% [markdown]
# The retrieved notebooks are supposed to be run in numerical order. To avoid having to wait a long time for computationally-intensive steps, the outputs will be downloaded from the polybox instead.
# If you are impatient, when meeting the following message, the following cell can be skipped.
# <div style="border:2px solid red; padding:10px; color:red; font-weight:bold; text-align:center;">
#   Output provided
# </div>
