# %%
# !rm -r data_sample
# !mkdir data_sample
# !cp -r ./data/Illumina_MAGs ./data_sample/
# !cp -r ./data/PacBio_MAGs ./data_sample/

# %%
# !cp -f ./data/MANIFEST ./data_sample/MANIFEST

####make sure to change "emotta" to your user name
# !sed -i "s|/home/jovyan/Interplanetary_Microbiome/data/PacBio_MAGs/|SCRATCH_DIR/data_sample/PB_|g" ./data_sample/MANIFEST
# !sed -i "s|/home/jovyan/Interplanetary_Microbiome/data/Illumina_MAGs/|SCRATCH_DIR/data_sample/IL_|g" ./data_sample/MANIFEST

# %%
# !for d in ./data_sample/Illumina_MAGs/*/; do cp -r "$d" "./data_sample/IL_$(basename "$d")"; done
# !for d in ./data_sample/PacBio_MAGs/*/; do cp -r "$d" "./data_sample/PB_$(basename "$d")"; done

# %%
# !rm -r ./data_sample/Illumina_MAGs
# !rm -r ./data_sample/PacBio_MAGs

# %%
# Remove temporary files
# !find ./data_sample -type f \( -name '*~' -o -name '*.tmp' -o -name '*.swp' \) -delete

# %%
# Create a zip archive
# !tar -czf data_sample.tar.gz ./data_sample
